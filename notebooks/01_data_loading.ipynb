# %%
import pandas as pd

# File paths
customers_path = "../data/customers.csv"
products_path = "../data/products.csv"
orders_path = "../data/orders.csv"
stores_path = "../data/stores.csv"

# Load datasets
customers = pd.read_csv(customers_path)
products = pd.read_csv(products_path)
orders = pd.read_csv(orders_path)
stores = pd.read_csv(stores_path)

#Quick validation
print("Customers: ", customers.shape)
print("Products: ", products.shape)
print("Orders: ", orders.shape)
print("Stores: ", stores.shape)

customers.head(), products.head(), orders.head(), stores.head()
# Out:
# Customers:  (3000, 6)
# Products:  (790, 6)
# Orders:  (1200, 8)
# Stores:  (8, 5)
# (  customer_id signup_date    gender age-group  city loyalty_status
#  0       C0001        Emma   Johnson    Female    34         London
#  1       C0002        Liam  Williams      Male    29     Manchester
#  2       C0003      Olivia     Brown    Female    41     Birmingham
#  3       C0004        Noah     Jones      Male    22          Leeds
#  4       C0005         Ava    Miller    Female    27        Bristol,
#    product_id category subcategory  price  cost  stock_level
#  0      P0001      Men    T-Shirts     25    12          120
#  1      P0002      Men    T-Shirts     28    14          140
#  2      P0003      Men    T-Shirts     22    10          160
#  3      P0004      Men    T-Shirts     30    15          110
#  4      P0005      Men    T-Shirts     27    13          130,
#    order_id customer_id product_id  quantity  order_date store_id  \
#  0    O0001       C0001      P0001         2  03/01/2024     S001
#  1    O0002       C0002      P0004         1  04/01/2024     S001
#  2    O0003       C0003      P0010         3  05/01/2024     S002
#  3    O0004       C0004      P0022         1  06/01/2024     S002
#  4    O0005       C0005      P0035         2  06/01/2024     S003
#
#    payment_method order_status
#  0           Card    Completed
#  1           Cash    Completed
#  2           Card    Completed
#  3           Card    Completed
#  4         Online    Completed  ,
#    store_id        city        manager  footfall   store_type
#  0     S001      London  Sophia Turner     52000     Flagship
#  1     S002  Birmingham  Daniel Harris     31000         Mall
#  2     S003  Manchester   Emily Clarke     28000  High Street
#  3     S004       Leeds  Michael Brown     26000         Mall
#  4     S005    Coventry   Olivia Patel     18000  High Street)
